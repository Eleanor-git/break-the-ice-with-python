# %% [markdown]
# # Question 75
#
# ### **Question**
#
# > **_Please write a program to randomly print a integer number between 7 and 15 inclusive._**
#
# ---
#
# ### Hints
#
# > **_Use random.randrange() to a random integer in a given range._**
#
# ---
#
# **Solution:**

# %%
import random

random.randrange(7,16)
# Out:
# 10

# %% [markdown]
# ---
#
# # Question 76
#
# ### **Question**
#
# > **_Please write a program to compress and decompress the string "hello world!hello world!hello world!hello world!"._**
#
# ---
#
# ### Hints
#
# > **_Use zlib.compress() and zlib.decompress() to compress and decompress a string._**
#
# ---
#
# **Solution:**

# %%
import zlib

str_bytecode = b"hello world!hello world!hello world!hello world!"

pressed_str = zlib.compress(str_bytecode)
pressed_str
# Out:
# b'x\x9c\xcbH\xcd\xc9\xc9W(\xcf/\xcaIQ\xcc \x82\r\x00\xbd[\x11\xf5'

# %%
zlib.decompress(pressed_str)
# Out:
# b'hello world!hello world!hello world!hello world!'

# %% [markdown]
# * The way converting byte string into unicode string:
# `str_bytecode.decode()`

# %% [markdown]
# ---
#
# # Question 77
#
# ### **Question**
#
# > **_Please write a program to print the running time of execution of "1+1" for 100 times._**
#
# ---
#
# ### Hints
#
# > **_Use timeit() function to measure the running time._**
#
# ---
#
#
#
# **Solutions:**

# %%
import timeit


def test():
    for _ in range(100):
        1 + 1

time = timeit.timeit(test)
print(f"It took {time} seconds")
# Out:
# It took 0.9389177910002218 seconds

# %% [markdown]
# ----
# 下面的部分只是我自己做的實驗，不用理會

# %%
from time import time

def test():
    for _ in range(100):
        1 + 1

        
t1 = time()
test()
t2 = time()
print(f"took {t2 - t1} seconds")
# Out:
# took 4.9114227294921875e-05 seconds

# %%
from time import time

t1 = time()

for _ in range(100):
    1 + 1

t2 = time()
print(f"took {t2 - t1} seconds")
# Out:
# took 6.699562072753906e-05 seconds

# %%
from time import time

t1 = time()

n = 1
while n <= 100:
    1 + 1
    n += 1

t2 = time()
print(f"took {t2 - t1} seconds")
# Out:
# took 0.00010085105895996094 seconds

# %% [markdown]
# ---
#
# # Question 78
#
# ### **Question**
#
# > **_Please write a program to shuffle and print the list [3,6,7,8]._**
#
# ---
#
# ### Hints
#
# > **_Use shuffle() function to shuffle a list._**
#
# ---
#
#
#
# **Solutions:**

# %%
import random

org_lst = [3,6,7,8]
random.shuffle(org_lst)
org_lst
# Out:
# [8, 7, 6, 3]

# %% [markdown]
# ---
#
# # Question 79
#
# ### **Question**
#
# > **_Please write a program to generate all sentences where subject is in ["I", "You"] and verb is in ["Play", "Love"] and the object is in ["Hockey","Football"]._**
#
# ---
#
# ### Hints
#
# > **_Use list[index] notation to get a element from a list._**
#
# ---
#
#
#
# **Solutions:**

# %%
import random

subjects = ["I", "You"]
verbs = ["Play", "Love"]
objects = ["Hocky", "Football", "Baseball", "Basketball", "Tennis"]

print("{0} {1} {2}".format(random.choice(subjects), random.choice(verbs), random.choice(objects)))
# Out:
# You Play Football

# %%
import random

subjects = ["I", "You"]
verbs = ["Play", "Love"]
objects = ["Hocky", "Football", "Baseball", "Basketball", "Tennis"]

for s in subjects:
    for v in verbs:
        for o in objects:
            print(f"{s} {v} {o}")
# Out:
# I Play Hocky
# I Play Football
# I Play Baseball
# I Play Basketball
# I Play Tennis
# I Love Hocky
# I Love Football
# I Love Baseball
# I Love Basketball
# I Love Tennis
# You Play Hocky
# You Play Football
# You Play Baseball
# You Play Basketball
# You Play Tennis
# You Love Hocky
# You Love Football
# You Love Baseball
# You Love Basketball
# You Love Tennis
