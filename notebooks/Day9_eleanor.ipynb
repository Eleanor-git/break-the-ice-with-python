# %% [markdown]
# # Question 26
#
# ### **Question:**
#
# > **_Define a function which can compute the sum of two numbers._**
#
# ---
#
# ### Hints:
#
# > **_Define a function with two numbers as arguments. You can compute the sum in the function and return the value._**
#
# ---
#
#
#
# **Solutions:**

# %%
def my_sum(n1, n2):
    return int(n1) + int(n2)

print(my_sum(10,3))
# Out:
# 13

# %%
def my_sum(*args):
    return sum(args)

my_sum(10,9)
# Out:
# 19

# %% [markdown]
# ---
#
# # Question 27
#
# ### **Question:**
#
# > **_Define a function that can convert a integer into a string and print it in console._**
#
# ---
#
# ### Hints:
#
# > **_Use str() to convert a number to string._**
#
# ---
#
#
#
# **Solutions:**

# %%
def int_converter(n):
    return str(n)


print(int_converter('10'))
print(type(int_converter('10')))
# Out:
# 10
# <class 'str'>

# %% [markdown]
# * Solution2: 用lambda的方式

# %%
num = [10,44,59]
print(list(map(lambda n: str(n), num)))
# Out:
# ['10', '44', '59']

# %% [markdown]
# ---
#
# # Question 28
#
# ### **Question:**
#
# > **_Define a function that can receive two integer numbers in string form and compute their sum and then print it in console._**
#
# ---
#
# ### Hints:
#
# > **_Use int() to convert a string to integer._**
#
# ---
#
#
#
# **Solutions:**

# %%
def my_sum(n1='0', n2='0'):
    return int(n1) + int(n2)


print(my_sum(8, 9))
# Out:
# 13

# %%
def my_sum(n1='', n2=''):
    return sum([int(n1), int(n2)])


print(my_sum('100', '99'))
# Out:
# 199

# %% [markdown]
# ---
#
# # Question 29
#
# ### **Question:**
#
# > **_Define a function that can accept two strings as input and concatenate them and then print it in console._**
#
# ---
#
# ### Hints:
#
# > **_Use + sign to concatenate the strings._**
#
# ---
#
#
#
# **Solutions:**

# %%
def str_concatenator(str1='', str2=''):
    return str1 + str2

print(str_concatenator(str1='happy', str2='birthday'))
# Out:
# happybirthday

# %%
my_concatenator = lambda str1, str2: f"{str1 + str2}"
print(my_concatenator('happy', 'birthday'))
# Out:
# happybirthday

# %% [markdown]
# ---
#
# # Question 30
#
# ### **Question:**
#
# > **_Define a function that can accept two strings as input and print the string with maximum length in console. If two strings have the same length, then the function should print all strings line by line._**
#
# ---
#
# ### Hints:
#
# > **_Use len() function to get the length of a string._**
#
# ---
#
#
#
# **Solutions:**

# %%
def str_len_com(str1='', str2=''):
    if len(str1) != len(str2):
        if len(str1) == max(len(str1), len(str2)):
            return str1
        else:
            return str2
    else:
        return f"{str1}, {str2}"

print(str_len_com('aaa', 'bbb'))
# Out:
# aaa, bbb
