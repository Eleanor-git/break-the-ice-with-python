# %% [markdown]
# # Question 20
#
# ### **Question:**
#
# > **_Define a class with a generator which can iterate the numbers, which are divisible by 7, between a given range 0 and n._**
#
# ---
#
# ### Hints:
#
# > **_Consider use class, function and comprehension._**
#
# ---
#
#
#
# **Solution: Python 3**

# %%
class My_generator:
    def __init__(self, upperbound):
        self.upperbound = int(upperbound)

    @staticmethod
    def chk_multiples_of7(num):
        if num % 7 == 0:
            return True
        return False

    def iterator(self):
        for i in range(self.upperbound + 1):
            if self.chk_multiples_of7(i):
                yield i


upper_bound = input('Prompt a number as the upper-bound: ')
# upper_bound = '10'
obj_mygen = My_generator(upper_bound)
obj_gen_iter = obj_mygen.iterator()

while True:
    try:
        print(next(obj_gen_iter))
    except StopIteration:
        break
# Out:
# Prompt a number as the upper-bound: 100
# 0
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77
# 84
# 91
# 98

# %%
class My_gen:
    def __init__(self, upper_bound):
        self.upper_bound = int(upper_bound)

    def inter_multipleof_7(self):
        for i in range(self.upper_bound + 1):
            if i % 7 == 0:
                yield i


obj_generator = My_gen(input("Prompt a number as the upper bound: "))

for i in obj_generator.inter_multipleof_7():
    print(i)
# Out:
# Prompt a number as the upper bound: 700
# 0
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77
# 84
# 91
# 98
# 105
# 112
# 119
# 126
# 133
# 140
# 147
# 154
# 161
# 168
# 175
# 182
# 189
# 196
# 203
# 210
# 217
# 224
# 231
# 238
# 245
# 252
# 259
# 266
# 273
# 280
# 287
# 294
# 301
# 308
# 315
# 322
# 329
# 336
# 343
# 350
# 357
# 364
# 371
# 378
# 385
# 392
# 399
# 406
# 413
# 420
# 427
# 434
# 441
# 448
# 455
# 462
# 469
# 476
# 483
# 490
# 497
# 504
# 511
# 518
# 525
# 532
# 539
# 546
# 553
# 560
# 567
# 574
# 581
# 588
# 595
# 602
# 609
# 616
# 623
# 630
# 637
# 644
# 651
# 658
# 665
# 672
# 679
# 686
# 693
# 700

# %% [markdown]
# ---
#
# # Question 21
#
# ### **Question:**
#
# > **_A robot moves in a plane starting from the original point (0,0). The robot can move toward UP, DOWN, LEFT and RIGHT with a given steps. The trace of robot movement is shown as the following:_**
#
# ```
# UP 5
# DOWN 3
# LEFT 3
# RIGHT 2
# ```
# > **_The numbers after the direction are steps. Please write a program to compute the distance from current position after a sequence of movement and original point. If the distance is a float, then just print the nearest integer._**
# > **_Example:_**
# > **_If the following tuples are given as input to the program:_**
#
# ```
# UP 5
# DOWN 3
# LEFT 3
# RIGHT 2
# ```
#
# > **_Then, the output of the program should be:_**
#
# ```
# 2
# ```
# ---
#
# ### Hints:
#
# > **_In case of input data being supplied to the question, it should be assumed to be a console input.Here distance indicates to euclidean distance.Import math module to use sqrt function._**
#
# ---
#
#
#
# **Solutions:**

# %%
from math import sqrt, pow

# initial value
x, y = 0, 0
org_coordinates = (x, y)

# moving
while True:
    try:
        move_lst = input("Prompt move (e.g. UP 5, DOWN 3): ").split(' ')
        if move_lst[0].upper() == "UP":
            y += int(move_lst[1])
        elif move_lst[0].upper() == "DOWN":
            y -= int(move_lst[1])

        elif move_lst[0].upper() == "RIGHT":
            x += int(move_lst[1])

        elif move_lst[0].upper() == "LEFT":
            x -= int(move_lst[1])
    except EOFError:
        break

# calculation Euclidean distance
euclidean_dist = round(
    sqrt(pow(org_coordinates[0] - x, 2) + pow(org_coordinates[1] - y, 2)))  # pow(x,y) = x^y (i.e. x to the power of y)
print(euclidean_dist)

# %%
# 為了要在jupyter notebook上面跑，把 exception改掉

from math import sqrt, pow

# initial value
x, y = 0, 0
org_coordinates = (x, y)

# moving
while True:
    move_lst = input("Prompt move (e.g. UP 5, DOWN 3): ").split()
    
    if not move_lst:
        break

    if move_lst[0].upper() == "UP":
        y += int(move_lst[1])

    elif move_lst[0].upper() == "DOWN":
        y -= int(move_lst[1])

    elif move_lst[0].upper() == "RIGHT":
        x += int(move_lst[1])

    elif move_lst[0].upper() == "LEFT":
        x -= int(move_lst[1])

# calculation Euclidean distance
euclidean_dist = round(
    sqrt(pow(org_coordinates[0] - x, 2) + pow(org_coordinates[1] - y, 2)))  # pow(x,y) = x^y (i.e. x to the power of y)
print("Distance:{0}".format(euclidean_dist))
# Out:
# Prompt move (e.g. UP 5, DOWN 3): up 4
# Prompt move (e.g. UP 5, DOWN 3): down 6
# Prompt move (e.g. UP 5, DOWN 3):
# Distance:2
